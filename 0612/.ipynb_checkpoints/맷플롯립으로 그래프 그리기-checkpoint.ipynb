# %%
import matplotlib.pyplot as plt

# %%
x = [i for i in range(10)]
plt.plot(x)
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2)
plt.show()

# %%
plt.plot(x, 'or') # o: 점, r: red
plt.show(x)

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r:')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'b')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'rv')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r<')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r.')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r3')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'r4')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'rp')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 's')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'rh')
plt.show()

# %%
x2 = [i ** 2 for i in range(10)]
plt.plot(x2, 'rd')
plt.show()
