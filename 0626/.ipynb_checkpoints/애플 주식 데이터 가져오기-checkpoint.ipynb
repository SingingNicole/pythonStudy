# %% [markdown]
# 애플주식 데이터 수집하여 저장하기

# %%
# !pip install finance-DataReader
# Out:
# Collecting finance-DataReader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: lxml in c:\users\soldesk\anaconda3\lib\site-packages (from finance-DataReader) (4.9.1)
# Requirement already satisfied: tqdm in c:\users\soldesk\anaconda3\lib\site-packages (from finance-DataReader) (4.64.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\soldesk\anaconda3\lib\site-packages (from finance-DataReader) (2.0.2)
# Requirement already satisfied: requests-file in c:\users\soldesk\anaconda3\lib\site-packages (from finance-DataReader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\soldesk\anaconda3\lib\site-packages (from finance-DataReader) (2.28.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\soldesk\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\soldesk\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\soldesk\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\soldesk\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\soldesk\anaconda3\lib\site-packages (from requests>=2.3.0->finance-DataReader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\soldesk\anaconda3\lib\site-packages (from requests>=2.3.0->finance-DataReader) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\soldesk\anaconda3\lib\site-packages (from requests>=2.3.0->finance-DataReader) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\soldesk\anaconda3\lib\site-packages (from requests>=2.3.0->finance-DataReader) (1.26.14)
# Requirement already satisfied: six in c:\users\soldesk\anaconda3\lib\site-packages (from requests-file->finance-DataReader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\soldesk\anaconda3\lib\site-packages (from tqdm->finance-DataReader) (0.4.6)
# Installing collected packages: finance-DataReader
# Successfully installed finance-DataReader-0.9.50

# %%
import FinanceDataReader as fdr
df=fdr.StockListing('KRX')
print(df.head())
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        72300          1      700
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       563000          3        0
# 2  000660  KR7000660001    SK하이닉스  KOSPI       112000          2    -1600
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       759000          1    12000
# 4  051910  KR7051910008      LG화학  KOSPI       705000          2    -4000
#
#    ChagesRatio    Open    High     Low   Volume        Amount  \
# 0         0.98   71700   72400   71500  5799773  418336086300
# 1         0.00  562000  565000  559000    68523   38516107000
# 2        -1.41  113100  113600  111200  2060564  230995379200
# 3         1.61  747000  759000  740000    22967   17235176000
# 4        -0.56  709000  712000  702000    67951   47932567000
#
#             Marcap      Stocks MarketId
# 0  431615278365000  5969782550      STK
# 1  131742000000000   234000000      STK
# 2   81536264880000   728002365      STK
# 3   54021066000000    71174000      STK
# 4   49767601815000    70592343      STK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import FinanceDataReader as fdr

# 애플 주식 데이터 수집
df = fdr.DataReader('AAPL','2022')

# 데이터 확인
print(df.head())
print(df.tail())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  180.434296
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.144287
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  173.405670
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.510956
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.679504
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# 2022-01-06   96904000
# 2022-01-07   86709100
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-06-16  186.729996  186.990005  184.270004  184.919998  184.919998
# 2023-06-20  184.410004  186.100006  184.410004  185.009995  185.009995
# 2023-06-21  184.899994  185.410004  182.589996  183.960007  183.960007
# 2023-06-22  183.740005  187.050003  183.669998  187.000000  187.000000
# 2023-06-23  185.550003  187.559998  185.009995  186.679993  186.679993
#
#                Volume
# Date
# 2023-06-16  101235600
# 2023-06-20   49799100
# 2023-06-21   49515700
# 2023-06-22   51245300
# 2023-06-23   53079300

# %%
# 주식 가격 시각화하기
plt.figure(figsize=(10, 6))
sns.lineplot(x=df.index, y=df['Close'])
plt.title('Apple Stock Price in 2022')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
#한달 간격으로 다운샘플링
df_month=df.resample("BM").mean()
print(df_month.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  170.201500  172.447999  167.639500  169.861500  168.390973
# 2022-02-28  169.635262  171.585263  167.580524  169.830001  168.539455
# 2022-03-31  164.806956  167.164348  162.939131  165.310435  164.088098
# 2022-04-29  167.479001  169.518500  165.083002  166.820999  165.587495
# 2022-05-31  148.324286  150.950952  145.364284  148.430477  147.504963
#
#                   Volume
# Date
# 2022-01-31  1.054223e+08
# 2022-02-28  8.565875e+07
# 2022-03-31  9.481740e+07
# 2022-04-29  8.438978e+07
# 2022-05-31  1.143353e+08

# %%
df_month['MA'] = df_month["Close"].rolling(2).mean()
print(df_month.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  170.201500  172.447999  167.639500  169.861500  168.390973
# 2022-02-28  169.635262  171.585263  167.580524  169.830001  168.539455
# 2022-03-31  164.806956  167.164348  162.939131  165.310435  164.088098
# 2022-04-29  167.479001  169.518500  165.083002  166.820999  165.587495
# 2022-05-31  148.324286  150.950952  145.364284  148.430477  147.504963
#
#                   Volume       rtn          MA
# Date
# 2022-01-31  1.054223e+08       NaN         NaN
# 2022-02-28  8.565875e+07 -0.000185  169.845750
# 2022-03-31  9.481740e+07 -0.026612  167.570218
# 2022-04-29  8.438978e+07  0.009138  166.065717
# 2022-05-31  1.143353e+08 -0.110241  157.625738

# %%
#수익률 추가하기
df_month['rtn']=df_month['Close'].pct_change()
print(df_month.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  170.201500  172.447999  167.639500  169.861500  168.390973
# 2022-02-28  169.635262  171.585263  167.580524  169.830001  168.539455
# 2022-03-31  164.806956  167.164348  162.939131  165.310435  164.088098
# 2022-04-29  167.479001  169.518500  165.083002  166.820999  165.587495
# 2022-05-31  148.324286  150.950952  145.364284  148.430477  147.504963
#
#                   Volume       rtn
# Date
# 2022-01-31  1.054223e+08       NaN
# 2022-02-28  8.565875e+07 -0.000185
# 2022-03-31  9.481740e+07 -0.026612
# 2022-04-29  8.438978e+07  0.009138
# 2022-05-31  1.143353e+08 -0.110241

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_month.index, y=df_month['rtn'])
plt.title('Apple Stock Returns in 2022-2023')
plt.xlabel('Date')
plt.ylabel('Returns')
plt.show()

# %%
# 2달씩 종가로 이동평균 구하기

df_month['MA']=df_month['Close'].rolling(2).mean()
print(df_month.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  170.201500  172.447999  167.639500  169.861500  168.390973
# 2022-02-28  169.635262  171.585263  167.580524  169.830001  168.539455
# 2022-03-31  164.806956  167.164348  162.939131  165.310435  164.088098
# 2022-04-29  167.479001  169.518500  165.083002  166.820999  165.587495
# 2022-05-31  148.324286  150.950952  145.364284  148.430477  147.504963
#
#                   Volume       rtn          MA
# Date
# 2022-01-31  1.054223e+08       NaN         NaN
# 2022-02-28  8.565875e+07 -0.000185  169.845750
# 2022-03-31  9.481740e+07 -0.026612  167.570218
# 2022-04-29  8.438978e+07  0.009138  166.065717
# 2022-05-31  1.143353e+08 -0.110241  157.625738

# %%
df_month.iloc[:,[3,7]].plot(figsize=(15,8))
# Out:
# <Axes: xlabel='Date'>

# %%
last_close=df_month['MA'].iloc[-2] # 이동평균선 60일 전 종가
print(last_close)
price=df_month['Close'].iloc[-1] # 오늘 종가
print(price)
if price>last_close:
    print('상승 장')
elif price<last_close:
    print('하락 장')
else:
    print('변화없음')
# Out:
# 168.83425894258374
# 182.7381249375
# 상승 장

# %%
df_month.to_csv('apple_data.csv')
